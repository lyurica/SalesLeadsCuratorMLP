# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn import preprocessing
# %matplotlib inline

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # Preprocessing data

# %%
training_data = pd.read_csv('training_data')

# %%
data = training_data.copy()

# %%
y = data.y_labels

# %%
X = data.drop(['y_labels'], axis = 1)

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X) 
X = pd.DataFrame(scaler.transform(X),columns =X.columns)
X.describe()
# Out:
#        Annual_revenue  D&b_annual_revenue   Fortune_100   Fortune_500  \
# count    3.533200e+04        3.533200e+04  3.533200e+04  3.533200e+04
# mean     3.710311e-17        6.650356e-17 -1.568718e-15  1.319218e-15
# std      1.000014e+00        1.000014e+00  1.000014e+00  1.000014e+00
# min     -5.724427e-03       -2.204103e-01 -3.531123e-02 -8.921533e-02
# 25%     -5.711367e-03       -1.008149e-01 -3.531123e-02 -8.921533e-02
# 50%     -5.688599e-03       -9.481923e-02 -3.531123e-02 -8.921533e-02
# 75%     -5.620237e-03       -7.638596e-02 -3.531123e-02 -8.921533e-02
# max      1.879636e+02        1.423647e+02  2.831960e+01  1.120884e+01
#
#        Ultimate_parent_zoominfo_revenue  Zoominfo_employee_count  \
# count                      3.533200e+04             3.533200e+04
# mean                      -1.593230e-16            -1.838772e-17
# std                        1.000014e+00             1.000014e+00
# min                       -2.039659e-01            -1.553461e-01
# 25%                       -2.022912e-01            -1.520364e-01
# 50%                       -1.968818e-01            -1.434906e-01
# 75%                       -1.657198e-01            -1.086508e-01
# max                        2.069891e+01             4.012187e+01
#
#        Zoominfo_finance_department_budget  Zoominfo_it_department_budget  \
# count                        3.533200e+04                   3.533200e+04
# mean                        -3.919104e-17                   8.392503e-17
# std                          1.000014e+00                   1.000014e+00
# min                         -1.796478e-01                  -1.858074e-01
# 25%                         -1.771095e-01                  -1.831259e-01
# 50%                         -1.695083e-01                  -1.753884e-01
# 75%                         -1.355355e-01                  -1.394370e-01
# max                          3.112794e+01                   3.090423e+01
#
#        Zoominfo_past_1_yr_employee_growth_rate  \
# count                             3.533200e+04
# mean                             -1.524951e-15
# std                               1.000014e+00
# min                              -3.767791e+00
# 25%                              -3.619453e-01
# 50%                              -2.740752e-01
# 75%                               1.020089e-01
# max                               3.463848e+01
#
#        Zoominfo_past_2yr_employee_growth_rate  ...  Sub_industry_Investment  \
# count                            3.533200e+04  ...             3.533200e+04
# mean                            -1.253449e-15  ...            -4.492075e-15
# std                              1.000014e+00  ...             1.000014e+00
# min                             -1.540401e+00  ...            -2.152116e-01
# 25%                             -4.817265e-01  ...            -2.152116e-01
# 50%                             -3.120809e-01  ...            -2.152116e-01
# 75%                              9.861170e-02  ...            -2.152116e-01
# max                              1.373200e+01  ...             4.646589e+00
#
#        Sub_industry_Materials  Sub_industry_Medical Devices  \
# count            3.533200e+04                  3.533200e+04
# mean            -2.560365e-15                  5.854912e-15
# std              1.000014e+00                  1.000014e+00
# min             -1.287349e-01                 -9.300525e-02
# 25%             -1.287349e-01                 -9.300525e-02
# 50%             -1.287349e-01                 -9.300525e-02
# 75%             -1.287349e-01                 -9.300525e-02
# max              7.767900e+00                  1.075208e+01
#
#        Sub_industry_Non-Profit  Sub_industry_Other Business Services  \
# count             3.533200e+04                          3.533200e+04
# mean             -6.262711e-16                         -1.019600e-16
# std               1.000014e+00                          1.000014e+00
# min              -1.200536e-01                         -1.912721e-01
# 25%              -1.200536e-01                         -1.912721e-01
# 50%              -1.200536e-01                         -1.912721e-01
# 75%              -1.200536e-01                         -1.912721e-01
# max               8.329614e+00                          5.228155e+00
#
#        Sub_industry_Pharmaceuticals  Sub_industry_Providers  \
# count                  3.533200e+04            3.533200e+04
# mean                  -8.194949e-15            1.063960e-14
# std                    1.000014e+00            1.000014e+00
# min                   -1.383948e-01           -2.409690e-01
# 25%                   -1.383948e-01           -2.409690e-01
# 50%                   -1.383948e-01           -2.409690e-01
# 75%                   -1.383948e-01           -2.409690e-01
# max                    7.225707e+00            4.149911e+00
#
#        Sub_industry_Real Estate  Sub_industry_Software  Sub_industry_Utilities
# count              3.533200e+04           3.533200e+04            3.533200e+04
# mean               6.026376e-15          -1.793160e-15           -2.199476e-15
# std                1.000014e+00           1.000014e+00            1.000014e+00
# min               -1.479677e-01          -2.253127e-01           -1.236420e-01
# 25%               -1.479677e-01          -2.253127e-01           -1.236420e-01
# 50%               -1.479677e-01          -2.253127e-01           -1.236420e-01
# 75%               -1.479677e-01          -2.253127e-01           -1.236420e-01
# max                6.758233e+00           4.438277e+00            8.087863e+00
#
# [8 rows x 59 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,  test_size=0.3,random_state=1)
print(X_train.shape,X_test.shape,y_train.shape, y_test.shape)
# Out:
# (24732, 59) (10600, 59) (24732,) (10600,)

# %% [markdown]
# # Training MLP Classifier

# %%
mlp = MLPClassifier(random_state=1)
mlp.fit(X_train, y_train)
y_predict_mlp = mlp.predict(X_test)

# %%
def binClassScore(predictions, actuals):
    results = pd.crosstab(predictions, actuals)
    tp = results[1][1]
    tn = results[0][0]
    fp = results[0][1]
    fn = results[1][0]
    n = results.sum().sum()

    acuracy = (tp + tn)/n
    recall = tp/(tp+fn)
    precision = tp/(tp+fp)
    f1 = 2*(precision*recall)/(precision-recall)
    return acuracy, recall, precision, f1

# %%
score = binClassScore(y_predict_mlp,y_test)
score
# Out:
# (0.9619811320754716,
#  0.13793103448275862,
#  0.5137614678899083,
#  0.37710437710437705)

# %% [markdown]
# # Parameter Tuning
# ## 1.) Tuning hidden layer size, activation function, solver type, and learning rate

# %%
cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=1)

param_grid = {
    'hidden_layer_sizes':[100 , 50, (100,100,100), (50,50,50), (25,25,25)],
    'activation': ['logistic','tanh','relu'],
    'solver': ['lbfgs','adam'],
    'learning_rate':['invscaling','adaptive']}

gridSearch = GridSearchCV(MLPClassifier(), param_grid, cv=cv,
                          scoring=['recall','f1'],refit='recall',verbose=2)
gridSearch.fit(X_train, y_train)
print('Score: ', gridSearch.best_score_)
print('Parameters: ', gridSearch.best_params_)
# Out:
# Fitting 1 folds for each of 60 candidates, totalling 60 fits
# [CV] END activation=logistic, hidden_layer_sizes=100, learning_rate=invscaling, solver=lbfgs; total time=   6.4s
# [CV] END activation=logistic, hidden_layer_sizes=100, learning_rate=invscaling, solver=adam; total time=  11.6s
# [CV] END activation=logistic, hidden_layer_sizes=100, learning_rate=adaptive, solver=lbfgs; total time=   6.6s
# [CV] END activation=logistic, hidden_layer_sizes=100, learning_rate=adaptive, solver=adam; total time=  11.5s
# [CV] END activation=logistic, hidden_layer_sizes=50, learning_rate=invscaling, solver=lbfgs; total time=   3.3s
# [CV] END activation=logistic, hidden_layer_sizes=50, learning_rate=invscaling, solver=adam; total time=   8.5s
# [CV] END activation=logistic, hidden_layer_sizes=50, learning_rate=adaptive, solver=lbfgs; total time=   3.3s
# [CV] END activation=logistic, hidden_layer_sizes=50, learning_rate=adaptive, solver=adam; total time=   8.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=lbfgs; total time=   0.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=adam; total time=  27.5s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=lbfgs; total time=   0.7s
# [CV] END activation=logistic, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=adam; total time=  27.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=lbfgs; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=adam; total time=  16.9s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=lbfgs; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=adam; total time=  16.7s
# [CV] END activation=logistic, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=adam; total time=  12.6s
# [CV] END activation=logistic, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=lbfgs; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=adam; total time=  12.6s
# [CV] END activation=tanh, hidden_layer_sizes=100, learning_rate=invscaling, solver=lbfgs; total time=  12.2s
# [CV] END activation=tanh, hidden_layer_sizes=100, learning_rate=invscaling, solver=adam; total time=  17.9s
# [CV] END activation=tanh, hidden_layer_sizes=100, learning_rate=adaptive, solver=lbfgs; total time=  12.2s
# [CV] END activation=tanh, hidden_layer_sizes=100, learning_rate=adaptive, solver=adam; total time=  17.6s
# [CV] END activation=tanh, hidden_layer_sizes=50, learning_rate=invscaling, solver=lbfgs; total time=   5.9s
# [CV] END activation=tanh, hidden_layer_sizes=50, learning_rate=invscaling, solver=adam; total time=  11.6s
# [CV] END activation=tanh, hidden_layer_sizes=50, learning_rate=adaptive, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, hidden_layer_sizes=50, learning_rate=adaptive, solver=adam; total time=  11.6s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=lbfgs; total time=  35.7s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=adam; total time=  45.5s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=lbfgs; total time=  34.8s
# [CV] END activation=tanh, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=adam; total time=  45.1s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=lbfgs; total time=  17.4s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=adam; total time=  25.8s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=lbfgs; total time=  17.6s
# [CV] END activation=tanh, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=adam; total time=  25.6s
# [CV] END activation=tanh, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=lbfgs; total time=   8.8s
# [CV] END activation=tanh, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=adam; total time=  16.7s
# [CV] END activation=tanh, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=lbfgs; total time=   9.1s
# [CV] END activation=tanh, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=adam; total time=  17.1s
# [CV] END activation=relu, hidden_layer_sizes=100, learning_rate=invscaling, solver=lbfgs; total time=   5.7s
# [CV] END activation=relu, hidden_layer_sizes=100, learning_rate=invscaling, solver=adam; total time=  11.9s
# [CV] END activation=relu, hidden_layer_sizes=100, learning_rate=adaptive, solver=lbfgs; total time=   5.7s
# [CV] END activation=relu, hidden_layer_sizes=100, learning_rate=adaptive, solver=adam; total time=   8.2s
# [CV] END activation=relu, hidden_layer_sizes=50, learning_rate=invscaling, solver=lbfgs; total time=   3.0s
# [CV] END activation=relu, hidden_layer_sizes=50, learning_rate=invscaling, solver=adam; total time=   8.8s
# [CV] END activation=relu, hidden_layer_sizes=50, learning_rate=adaptive, solver=lbfgs; total time=   2.8s
# [CV] END activation=relu, hidden_layer_sizes=50, learning_rate=adaptive, solver=adam; total time=   8.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=lbfgs; total time=  17.2s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100, 100), learning_rate=invscaling, solver=adam; total time=  27.8s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=lbfgs; total time=  16.9s
# [CV] END activation=relu, hidden_layer_sizes=(100, 100, 100), learning_rate=adaptive, solver=adam; total time=  25.4s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=lbfgs; total time=   7.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50, 50), learning_rate=invscaling, solver=adam; total time=  17.2s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=lbfgs; total time=   7.5s
# [CV] END activation=relu, hidden_layer_sizes=(50, 50, 50), learning_rate=adaptive, solver=adam; total time=  17.2s
# [CV] END activation=relu, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=lbfgs; total time=   3.7s
# [CV] END activation=relu, hidden_layer_sizes=(25, 25, 25), learning_rate=invscaling, solver=adam; total time=  12.3s
# [CV] END activation=relu, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=lbfgs; total time=   3.8s
# [CV] END activation=relu, hidden_layer_sizes=(25, 25, 25), learning_rate=adaptive, solver=adam; total time=  12.9s
# Score:  0.1336405529953917
# Parameters:  {'activation': 'tanh', 'hidden_layer_sizes': 50, 'learning_rate': 'adaptive', 'solver': 'lbfgs'}

# %% [markdown]
# ## 2.) Tuning alpha, learning rate init's, max iterations, and shuffle

# %%
cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=1)
param_grid = {
    'hidden_layer_sizes':[50],
    'activation': ['tanh'],
    'solver': ['lbfgs'],
    'alpha': [0,0.0005,0.0001,0.0005,0.001],
    'learning_rate':['adaptive'],
    'learning_rate_init': [0,0.0001,0.0005,0.001, 0.005,0.01],
    'max_iter': [200,500],
    'shuffle': [True,False] 
}

gridSearch = GridSearchCV(MLPClassifier(), param_grid, cv=cv,
                          scoring='recall',verbose=2)
gridSearch.fit(X_train, y_train)
print('Score: ', gridSearch.best_score_)
print('Parameters: ', gridSearch.best_params_)
# Out:
# Fitting 1 folds for each of 120 candidates, totalling 120 fits
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.5s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.2s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.4s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.2s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.0s
# [CV] END activation=tanh, alpha=0, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.4s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=False, solver=lbfgs; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.0s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0.0001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.2s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.4s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.5s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.3s
# [CV] END activation=tanh, alpha=0.0005, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=200, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=True, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0, max_iter=500, shuffle=False, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0001, max_iter=500, shuffle=False, solver=lbfgs; total time=  16.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=True, solver=lbfgs; total time=   7.0s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.5s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=True, solver=lbfgs; total time=  16.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.0005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.9s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.001, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.5s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.8s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.005, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.4s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=True, solver=lbfgs; total time=   6.3s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=200, shuffle=False, solver=lbfgs; total time=   6.1s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=True, solver=lbfgs; total time=  15.6s
# [CV] END activation=tanh, alpha=0.001, hidden_layer_sizes=50, learning_rate=adaptive, learning_rate_init=0.01, max_iter=500, shuffle=False, solver=lbfgs; total time=  15.6s
# Score:  0.18433179723502305
# Parameters:  {'activation': 'tanh', 'alpha': 0.0005, 'hidden_layer_sizes': 50, 'learning_rate': 'adaptive', 'learning_rate_init': 0.005, 'max_iter': 500, 'shuffle': False, 'solver': 'lbfgs'}

# %% [markdown]
# # Model validation
# ## Checking if random state has disproportionate influence

# %%
X_train_s, X_tune, y_train_s, y_tune = train_test_split(X_train, y_train,
                                                        test_size=0.2)
for i in range(15):
    mlp = MLPClassifier(activation='tanh', alpha = 0.005, hidden_layer_sizes= [50],
                        learning_rate='adaptive',learning_rate_init = 0.005, max_iter = 500, shuffle = False,
                        solver='lbfgs',  random_state=i)
    
    mlp.fit(X_train_s, y_train_s)
    y_predict_mlp = mlp.predict(X_tune)

    result = binClassScore(y_predict_mlp,y_tune)
    print(f'{i}\t Accuracy: {result[0]}, Recall: {result[1]}, Precision: {result[2]}, F-Score: {result[3]}')
# Out:
# 0	 Accuracy: 0.9338993329290479, Recall: 0.16113744075829384, Precision: 0.18478260869565216, F-Score: 2.5185185185185195
# 1	 Accuracy: 0.9355164746310896, Recall: 0.14691943127962084, Precision: 0.18235294117647058, F-Score: 1.5121951219512193
# 2	 Accuracy: 0.9334950475035375, Recall: 0.12796208530805686, Precision: 0.1569767441860465, F-Score: 1.384615384615384
# 3	 Accuracy: 0.9401657570244593, Recall: 0.16587677725118483, Precision: 0.22580645161290322, F-Score: 1.2499999999999998
# 4	 Accuracy: 0.9387507580351728, Recall: 0.16113744075829384, Precision: 0.2125, F-Score: 1.3333333333333335
# 5	 Accuracy: 0.9345057610673135, Recall: 0.17535545023696683, Precision: 0.19786096256684493, F-Score: 3.0833333333333326
# 6	 Accuracy: 0.9359207600566, Recall: 0.16587677725118483, Precision: 0.19886363636363635, F-Score: 2.0
# 7	 Accuracy: 0.9361229027693552, Recall: 0.13744075829383887, Precision: 0.17791411042944785, F-Score: 1.2083333333333335
# 8	 Accuracy: 0.9375379017586416, Recall: 0.1895734597156398, Precision: 0.2247191011235955, F-Score: 2.4242424242424234
# 9	 Accuracy: 0.9387507580351728, Recall: 0.15639810426540285, Precision: 0.2088607594936709, F-Score: 1.2452830188679245
# 10	 Accuracy: 0.936931473620376, Recall: 0.1895734597156398, Precision: 0.22099447513812154, F-Score: 2.666666666666666
# 11	 Accuracy: 0.9385486153224176, Recall: 0.14691943127962084, Precision: 0.2, F-Score: 1.1071428571428565
# 12	 Accuracy: 0.9351121892055791, Recall: 0.12796208530805686, Precision: 0.16463414634146342, F-Score: 1.1489361702127654
# 13	 Accuracy: 0.9332929047907823, Recall: 0.13270142180094788, Precision: 0.16, F-Score: 1.555555555555556
# 14	 Accuracy: 0.9343036183545583, Recall: 0.15165876777251186, Precision: 0.1797752808988764, F-Score: 1.9393939393939408

# %% [markdown]
# ## Final model

# %%
mlp = MLPClassifier(hidden_layer_sizes= [50] ,activation='tanh',
                        learning_rate='adaptive', solver='lbfgs',  random_state=1)

mlp.fit(X_train_s, y_train_s)
y_predict_mlp = mlp.predict(X_test)
result = binClassScore(y_predict_mlp,y_test)
print(f'Accuracy: {result[0]}, Recall: {result[1]}, Precision: {result[2]}, F-Score: {result[3]}')
# Out:
# Accuracy: 0.9492452830188679, Recall: 0.1748768472906404, Precision: 0.2591240875912409, F-Score: 1.075757575757576
